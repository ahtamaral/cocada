# %% [markdown]
# # Computação científica e análise de dados - 2023.2
# # **Lista 3**: Interpolação, regressão e sistemas dinâmicos
# ## **Autor:** Artur Henrique Teixeira do Amaral
# ## **DRE:** 122032113

# %% [markdown]
# ### Exercício 02

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Item 1

# %%
using Random, Printf, LinearAlgebra

# Função que define polinômio de grau 5. Coeficientes arbitrários.
function f(x)
    y = 1*x^5 + 1*x^4 + 1*x^3 + 1*x^2 + x^1 + 1
    return y
end

random_xs = -0.1 .+ 0.2 * rand(30)

ys = []

for i in 1:30
    tmp = f(random_xs[i])
    push!(ys, tmp)
end

display(size(random_xs))
display(size(ys))
# Out:
# (30,)
# (30,)

# %% [markdown]
# #### Item 2

# %%
# Implementação de regressão fornecida pelo professor
function vandermonde(x,y,grau)
    n,=size(y)
    V=zeros(n,grau+1)
    for i=1:n #linhas
        for j=1:(grau+1)
            V[i,j]=x[i]^(j-1)
        end
    end
    return V
end

function regressão(x,y,grau)
    V=vandermonde(x,y,grau)
    c=V\y #mínimos quadrados
    return c
end

for i in 0:29
    a = regressão(ys, random_xs, i)
    display(a)
end
# Out:
# 1-element Vector{Float64}:
#  -0.006448656757541658
# 2-element Vector{Float64}:
#  -1.0091179912209451
#   1.006363297873935
# 3-element Vector{Float64}:
#  -2.002166276479352
#   2.998898946163453
#  -0.9967492940432673
# 4-element Vector{Float64}:
#  -2.998143141122304
#   5.986370672084905
#  -3.9783390760326545
#   0.9901187900885755
# 5-element Vector{Float64}:
#  -3.9841135275487973
#   9.92690866565463
#  -9.876123634912512
#   4.907991837747634
#  -0.9746632602663603
# 6-element Vector{Float64}:
#   -4.908156664532712
#   14.542874810147925
#  -19.090307525916216
#   14.095231336950887
#   -5.550255672655133
#    0.9106137210633863
# 7-element Vector{Float64}:
#   -4.637702816190824
#   12.920963505604613
#  -15.040871551233428
#    8.707507898933722
#   -1.5213862354521444
#   -0.6948652560889329
#    0.2663544551596517
# 8-element Vector{Float64}:
#     1.790064101152946
#   -32.05657513744609
#   119.74713988013477
#  -215.5417918278943
#   222.17501194885767
#  -134.48839885710717
#    44.69223192325054
#    -6.3176820319170535
# 9-element Vector{Float64}:
#     30.37145359419444
#   -260.3688033196025
#    917.1699546629085
#  -1806.0862159187209
#   2203.7881213081882
#  -1713.5826823646712
#    830.6763276168336
#   -229.73574728562423
#     27.76759170647465
# 10-element Vector{Float64}:
#     117.33016076751632
#   -1042.6158321457428
#    4042.99250557789
#   -9088.468638218115
#   13104.855656610083
#  -12586.47832501894
#    8056.74489891593
#   -3315.3768442301416
#     795.9735092592919
#     -84.95709151775714
# 11-element Vector{Float64}:
#     66.28729749487098
#   -532.7378176651678
#   1752.0665580847935
#  -2991.512011293438
#   2461.3265287180757
#    148.63194648827997
#  -2520.1636750691396
#   2705.4987883823737
#  -1452.2100510223256
#    412.27853083723585
#    -49.46609495554418
end
# Out:
# grau 1: 1.425162
# grau 2: 3.741066
# grau 3: 7.850670
# grau 4: 15.394572
# grau 5: 28.815537
# grau 6: 22.212080
# grau 7: 362.373625
# grau 8: 3564.895916
# grau 9: 22511.046103
# grau 10: 5859.998961
# grau 11: 2083.995547
# grau 12: 873.799674
# grau 13: 409.045970
# grau 14: 2123.709656
# grau 15: 1095.238841
# grau 16: 596.216317
# grau 17: 340.970050
# grau 18: 202.682306
# grau 19: 124.101593
# grau 20: 77.563896
# grau 21: 49.545508
# grau 22: 31.841583
# grau 23: 164.964816
# grau 24: 112.591403
# grau 25: 77.872392
# grau 26: 54.444059
# grau 27: 38.331367
# grau 28: 27.112255
# grau 29: 2589.512722
# grau 30: 13.938431
# grau 31: 9.970952
# grau 32: 49.012740
# grau 33: 36.691378
# grau 34: 27.784780
# grau 35: 21.055451
# grau 36: 15.940661
# grau 37: 12.181787
# grau 38: 9.317656
# grau 39: 7.246293
# grau 40: 5.728721
# grau 41: 4.705655
# grau 42: 4.022685
# grau 43: 3.623725
# grau 44: 3.415892
# grau 45: 3.319967
# grau 46: 3.286287
# grau 47: 6.401449
# grau 48: 3.277697
# grau 49: 3.276865
# grau 50: 3.944330

# %% [markdown]
# Observando o comportamento da regressão para polinômios de grau 1 até 50, observamos que, anomalamente, a norma do vetor de coeficientes justamente no grau 29 é muito mais alta, e depois desce lentamente até estabilizar-se em zero. Não sei explicar este fenômeno.
#
# O mesmo comportamente anômalo é observado se mudarmos os coeficientes do polinômio que gera os pontos. O grau 29 é um ponto onde o resultado dá um número muito destoante dos demais e que, a partir dali, a norma do vetor de coeficientes tende a cair para zero.

# %% [markdown]
# #### Item 4

# %%
# Recebe uma lista com o domínio da função (Pontos X gerados inicialmente).
# Recebe um vetor a com parâmetros ajustados para aquele conjunto de pontos.
# Infere o grau do polinômio baseado no tamanho de a.
function f_adjusted(x,a)
        
    degree = size(a)[1] - 1
#     @printf("Degree of adjusted polynomial: %d", degree)
    
    V = vandermonde(x, x, degree)
    
    return V*a
    
end
    
for i in 1:30
    a = regressão(ys, random_xs, i)
    b = f_adjusted(random_xs, a)
end
    
display(norm(b-ys))
# Out:
# Degree of adjusted polynomial: 1Degree of adjusted polynomial: 2Degree of adjusted polynomial: 3Degree of adjusted polynomial: 4Degree of adjusted polynomial: 5Degree of adjusted polynomial: 6Degree of adjusted polynomial: 7Degree of adjusted polynomial: 8Degree of adjusted polynomial: 9Degree of adjusted polynomial: 10Degree of adjusted polynomial: 11Degree of adjusted polynomial: 12Degree of adjusted polynomial: 13Degree of adjusted polynomial: 14Degree of adjusted polynomial: 15Degree of adjusted polynomial: 16Degree of adjusted polynomial: 17Degree of adjusted polynomial: 18Degree of adjusted polynomial: 19Degree of adjusted polynomial: 20Degree of adjusted polynomial: 21Degree of adjusted polynomial: 22Degree of adjusted polynomial: 23Degree of adjusted polynomial: 24Degree of adjusted polynomial: 25Degree of adjusted polynomial: 26Degree of adjusted polynomial: 27Degree of adjusted polynomial: 28Degree of adjusted polynomial: 29Degree of adjusted polynomial: 30
# 10.278193811706975

# %% [markdown]
# ### Exercício 04

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Pré-processamento dos dados
#
# Os dados disponibilizados pelo professor possuem uma relação entre data do ano e peso em quilogramas. Para adequar melhor ao nosso ferramental matemático, transformei as datas em números inteiros, que representam a quantidade de dias passados desde o primeiro dia de medição, que foi 26/10. Essa etapa foi feita em Python por conta familiaridade minha com a linguagem. O arquivo tratado aqui já foi pré-processado anteriormente.

# %%
# Instalando pacotes necessários
import Pkg;
Pkg.add("DataFrames");
Pkg.add("CSV");
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`

# %%
using CSV, DataFrames, LinearAlgebra

csv_file_path = "processed-pesagem.csv"

# Lê CSV em um dataframe.
df = CSV.File(csv_file_path, delim=',') |> DataFrame

# Extrai colunas do dataframe.
days = df[:, 1]
weights = df[:, 2]

# Converte DataFrame em arrays convencionais
days = collect(days);
weights = collect(weights);

size(days)
# Out:
# (68,)

# %% [markdown]
# Nesse ponto, o vetor *weights* possui as medições de peso do João, e *days* possui os dias decorridos a partir de 26 de outubro, que virou o elemento zero da lista.
#
# Utilizarei um modelo linear como base da regressão, pois, dada uma observação inicial dos dados, não parece existr motivo para utilização de um modelo mais sofisticado.
#
# Logo, sejam $w$ a variável independente que representa as medidas de peso e $d$ a variável que representa os dias após a medida inicial, temos o seguinte modelo:
#
# \begin{equation}
# d(w) = a_0 + a_1w
# \end{equation}
#
# Como temos 68 medições, temos uma matriz de Vandermonde $V_{68x2}$ representando os pesos no polinômio e uma matriz $b_{68x1}$ contendo os dias.
#
# Iremos encontrar o vetor $a$ contendo nosso parâmetros de ajuste ao resolver a **equação normal do sistema linear obtido do modelo:
#
# \begin{equation}
# Va = b
# \end{equation}
#
# \begin{equation}
# V^{t}Va = V^{t}b
# \end{equation}

# %%
# Função fornecida pelo professor. Monta a matriz de Vandermonde conforme nossos dados.
function vandermonde(x,y,grau)
    n,=size(y)
    V=zeros(n,grau+1)
    for i=1:n #linhas
        for j=1:(grau+1)
            V[i,j]=x[i]^(j-1)
        end
    end
    return V
end

# Função que implementa polinômio do primeiro grau.
function f(a, x)
    y = a[1] + a[2]*x
    return y
end
# Out:
# f (generic function with 1 method)

# %%
# Obtendo matrizes da equação normal.
b = days
V = vandermonde(weights, days, 1)

VtV = transpose(V) * V;
Vtb = transpose(V) * b;

# Resolvendo equação normal para a. Isso nos dá os coeficientes do polinômio.
a = VtV\Vtb
# Out:
# 2-element Vector{Float64}:
#  1576.9484267317455
#   -12.93456085571097

# %%
result = f(a,110)
print("O peso 110 kg será atingido ")
print(trunc(Int,result))
println(" dias após a medição inicial.")
# Out:
# O peso 110 kg será atingido 154 dias após a medição inicial.

# %% [markdown]
# O resultado acima nos indica que, a partir de uma análise da tendência, o João pesará 110kg 154 dias após a primeira medida, que foi 26 de outubro. Ou seja, ele pesará 110kg por volta do dia 29 de março do ano seguinte.
